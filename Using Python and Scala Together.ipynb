# %% [markdown]
# # Using Python and Scala Together
# # <img src="https://www.python.org/static/community_logos/python-logo-generic.svg" width="350" /> &nbsp; + &nbsp; &nbsp; &nbsp; <img src="https://www.scala-lang.org/resources/img/scala-logo-red-spiral-dark.png" />
#
# Databricks supports four different programming languages when writing notebooks:  Python, R, Scala, and SQL.  You can even [mix in different languages](https://docs.databricks.com/notebooks/notebooks-use.html#mix-languages) within
# the same notebook.  This turns out to be a very powerful feature because data scientists who are comfortable using Python sometimes need to use custom Spark libraries, many of which are written in Scala.
#
# In this notebook, we will show how a data scientist can use Python and the PySpark API to prepare some data.  We will show how the data from the Python environment can be shared with the Scala environment and how a custom
# Scala library can be used to operate on that data. Finally, we will see that Python can be used to continue the data science process by picking up the data created by the Scala process.
#
# For this example, we will be using the [Smart Imputation library](https://github.com/JMailloH/Smart_Imputation), which allows us to harness the power of Spark to do KNN imputation of missing values on a large dataset distributed
# across a cluster.

# %% [markdown]
# # Step 0: Install the Library
#
# To use this example notebook, you will need to install the "Smart Imputation" library in your cluster.  Open the "Clusters" admin page in Databricks and select your cluster.  On the "Libraries" tab, click the "Install New" button.  The library source will be Maven. You only need to supply the following coordinates:  `JMailloH:Smart_Imputation:1.0`

# %% [markdown]
# ## Step 1:  Prepare Data in Python
# For this example, we will need some data with missing values that we can impute.  We begin by using Python to create a Spark dataframe.  For this example, we will use the flight delay sample dataset that is included with Databricks.

# %%
df = (spark.read
        .option("header", "true")
        .option("inferSchema", "true")
        .csv("/databricks-datasets/flights/departuredelays.csv")
        .cache()
     )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# The dataset has a couple of string factors.  Let's index those into numeric features... like we would do in a typical machine learning project

# %%
from pyspark.ml import Pipeline
from pyspark.ml.feature import StringIndexer

string_columns = [dt[0] for dt in df.dtypes if dt[1] == 'string']

indexers = [StringIndexer(inputCol=c, outputCol=c+"_index").fit(df) for c in string_columns ]

pipeline = Pipeline(stages=indexers)
df_indexed = pipeline.fit(df).transform(df).drop(*string_columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Our example project is to impute missing values in our dataset.  Let's see how many values in the `delay` column are null...

# %%
import pyspark.sql.functions as pyf

df_indexed.withColumn("delay_is_null", pyf.col("delay").isNull()).groupBy("delay_is_null").count().show()
print("Total Rows: {:,}".format(df_indexed.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+-------+
# delay_is_null|  count|
# +-------------+-------+
#         false|1391578|
# +-------------+-------+
#
# Total Rows: 1,391,578
# </div>

# %% [markdown]
# As the query above shows, there are no missing values in this dataset.  That's no problem.  Let's just randomly select 20% of the rows and set the `delay` column to null for those rows.

# %%
splits = df_indexed.randomSplit([0.8, 0.2])
splits[1] = splits[1].withColumn("delay", pyf.lit(None))
df_indexed = splits[0].union(splits[1]).orderBy("origin_index", "date")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Re-run the same query as above to see how many values in the `delay` column are null.

# %%
df_indexed.withColumn("delay_is_null", pyf.col("delay").isNull()).groupBy("delay_is_null").count().show()
print("Total Rows: {:,}".format(df_indexed.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+-------+
# delay_is_null|  count|
# +-------------+-------+
#          true| 278219|
#         false|1113359|
# +-------------+-------+
#
# Total Rows: 1,391,578
# </div>

# %% [markdown]
# We now have a Spark dataframe referenced in Pyspark that contains the data we want to work with.  However, we need to use that same Spark dataframe in Scala.  To do this, we simply register our Spark dataframe as a "temp view" in Spark.
# We will name the temp view as `flights` and then be able to access is it by that name in Scala (or any other language environment that supports Spark).

# %%
df_indexed.createOrReplaceTempView("flights")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Step 2:  Read the Data in Scala
#
# Now we can switch over to Scala.  To reference the same Spark dataframe we created with Python, we simply have to access our temp view by name... just as if it was a regular table.
#
# Once we can access the Spark dataframe in Scala, we can continue processing it.  The "Smart Imputation" library that we will be using in this example expects RDD's containing all of the values in a single, comma-separated string.
# It also expects the missing values to be represented by a question mark `?`.  We can perform those conversions easily with Scala.

# %%
# %scala
val dfIndexed = spark.table("flights").cache()
val rdd_data = dfIndexed.map(row => row.mkString(",").replace("null", "?")).rdd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dfIndexed: org.apache.spark.sql.Dataset[org.apache.spark.sql.Row] = [date: int, delay: int ... 3 more fields]
# rdd_data: org.apache.spark.rdd.RDD[String] = MapPartitionsRDD[105] at rdd at command-201076224977847:2
# </div>

# %% [markdown]
# The "Smart Imputation" library also needs a header file that describes the dataset.  It expects this file to be in the [ARFF](https://www.cs.waikato.ac.nz/ml/weka/arff.html) format.  This little snippet of code will create the
# file for us.

# %%
# %scala

import org.apache.spark.sql.functions.{min, max}

var arffHeader = "@relation flights";

for ((c,d) <- dfIndexed.dtypes) {
  var attributeType = d match {
      case "IntegerType"  => "integer"
      case "DoubleType"  => "real"
      case _  => "Invalid Type"
  }
  
  var line = "\n@attribute " + c + " " + attributeType

  if (attributeType == "integer" || attributeType == "real") {
    // get the range of values in the column
    var range = dfIndexed.agg(min(c), max(c)).head
    var rangeText = " [" + range(0) + ", " + range(1) + "]"
    line = line.concat(rangeText)
  }
  
  arffHeader = arffHeader.concat(line)
}

arffHeader = arffHeader.concat("\n@inputs " + dfIndexed.columns.filter(_ != "distance").mkString(", "))
arffHeader = arffHeader.concat("\n@outputs distance")
arffHeader = arffHeader.concat("\n@data")

dbutils.fs.put("/knn/data.header", arffHeader, true)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Wrote 303 bytes.
# import org.apache.spark.sql.functions.{min, max}
# arffHeader: String =
# @relation flights
# @attribute date integer [1010005, 3312359]
# @attribute delay integer [-112, 1642]
# @attribute distance integer [21, 4330]
# @attribute origin_index real [0.0, 254.0]
# @attribute destination_index real [0.0, 302.0]
# @inputs date, delay, origin_index, destination_index
# @outputs distance
# @data
# arffHeader: String = @relation flights
# @attribute date integer [1010005, 3312359]
# @attribute delay integer [-112, 1642]
# @attribute distance integer [21, 4330]
# @attribute origin_index real [0.0, 254.0]
# @attribute destination_index real [0.0, 302.0]
# @inputs date, delay, origin_index, destination_index
# @outputs distance
# @data
# arffHeader: String = @relation flights
# @attribute date integer [1010005, 3312359]
# @attribute delay integer [-112, 1642]
# @attribute distance integer [21, 4330]
# @attribute origin_index real [0.0, 254.0]
# @attribute destination_index real [0.0, 302.0]
# @inputs date, delay, origin_index, destination_index
# @outputs distance
# @data
# arffHeader: String = @relation flights
# @attribute date integer [1010005, 3312359]
# @attribute delay integer [-112, 1642]
# @attribute distance integer [21, 4330]
# @attribute origin_index real [0.0, 254.0]
# @attribute destination_index real [0.0, 302.0]
# @inputs date, delay, origin_index, destination_index
# @outputs distance
# @data
# res1: Boolean = true
# </div>

# %% [markdown]
# Now we have everything we need to call the "Smart Imputation" library.  So let's kick it off!  The process can take a while to run.

# %%
# %scala

import org.apache.spark.mllib.preprocessing.kNNI_IS.KNNI_IS

val K = 3
val distanceType = 2       // MANHATTAN = 1 ; EUCLIDEAN = 2 ; HVDM = 3
val pathHeader = "/dbfs/knn/data.header"
val numPartitionMap = 10
val version = "global"     // "global" or "local"

val knni = KNNI_IS.setup(rdd_data, K, distanceType, pathHeader, numPartitionMap, version)
val imputedData = knni.imputation(sc)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">=&gt; NumberIterations &quot;1&quot;
# ------------------------------------0
#  &gt;&gt; processing: date, delay, origin_index, destination_index
#    &gt; inputs attribute considered: date.
#    &gt; inputs attribute considered: delay.
#    &gt; inputs attribute considered: origin_index.
#    &gt; inputs attribute considered: destination_index.
#  &gt;&gt; processing:  distance
#    &gt; outputs attribute considered: distance.
#  &gt;&gt; Processing inputs and outputs
# import org.apache.spark.mllib.preprocessing.kNNI_IS.KNNI_IS
# K: Int = 3
# distanceType: Int = 2
# pathHeader: String = /dbfs/knn/data.header
# numPartitionMap: Int = 10
# version: String = global
# knni: org.apache.spark.mllib.preprocessing.kNNI_IS.KNNI_IS = org.apache.spark.mllib.preprocessing.kNNI_IS.KNNI_IS@278ff45a
# imputedData: org.apache.spark.rdd.RDD[Array[String]] = UnionRDD[152] at union at kNNI_IS.scala:174
# </div>

# %% [markdown]
# The "Smart Imputation" library returns an RDDs of arrays of strings.  Let's convert the RDD's to a dataframe, extract the array elements to individual columns, and cast the values back to their original data types.
# (We also save the imputed data to a parquet file.  We don't have to do this... I just did it because the imputation process took so long that I didn't want to re-run it if I needed this data again.)

# %%
# %scala

import org.apache.spark.sql.functions._

var imputedDF = imputedData.toDF()
var i = 1

for ((c,d) <- dfIndexed.dtypes) {
  imputedDF = imputedDF.withColumn(c, element_at($"value", i).cast(d.replaceAll("Type$", "")))
  i += 1
}

imputedDF = imputedDF.drop($"value")

imputedDF.write.mode("overwrite").parquet("/knn/output")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">import org.apache.spark.sql.functions._
# imputedDF: org.apache.spark.sql.DataFrame = [date: int, delay: int ... 3 more fields]
# i: Int = 6
# imputedDF: org.apache.spark.sql.DataFrame = [date: int, delay: int ... 3 more fields]
# </div>

# %% [markdown]
# One last step in Scala.  We need to register our Spark dataframe containing the imputed data as a temp view.  This will allow us to pick up this new dataframe in Python.

# %%
# %scala
imputedDF.createOrReplaceTempView("imputed")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Step 3:  Back to Python
#
# Now we can return to Python and continue processing the imputed data.  We can access the Spark dataframe containing the imputed data simply by referencing the name of the temp view we registered.

# %%
imputed_df = spark.table("imputed")

imputed_df.withColumn("delay_is_null", pyf.col("delay").isNull()).groupBy("delay_is_null").count().show()
print("Total Rows: {:,}".format(imputed_df.count()))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+-------+
# delay_is_null|  count|
# +-------------+-------+
#         false|1224554|
# +-------------+-------+
#
# Total Rows: 1,224,554
# </div>

# %% [markdown]
# From here on out... we can do just some regular analysis with Python, just like we normally would.

# %%
display(df_indexed)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>delay</th><th>distance</th><th>origin_index</th><th>destination_index</th></tr></thead><tbody><tr><td>1010600</td><td>-3</td><td>599</td><td>0.0</td><td>5.0</td></tr><tr><td>1010615</td><td>-3</td><td>513</td><td>0.0</td><td>21.0</td></tr><tr><td>1010630</td><td>-5</td><td>351</td><td>0.0</td><td>10.0</td></tr><tr><td>1010630</td><td>-1</td><td>788</td><td>0.0</td><td>18.0</td></tr><tr><td>1010640</td><td>-4</td><td>517</td><td>0.0</td><td>19.0</td></tr><tr><td>1010700</td><td>-2</td><td>636</td><td>0.0</td><td>1.0</td></tr><tr><td>1010700</td><td>1</td><td>197</td><td>0.0</td><td>9.0</td></tr><tr><td>1010700</td><td>9</td><td>501</td><td>0.0</td><td>20.0</td></tr><tr><td>1010700</td><td>18</td><td>662</td><td>0.0</td><td>12.0</td></tr><tr><td>1010707</td><td>2</td><td>527</td><td>0.0</td><td>2.0</td></tr><tr><td>1010720</td><td>0</td><td>369</td><td>0.0</td><td>35.0</td></tr><tr><td>1010725</td><td>-3</td><td>516</td><td>0.0</td><td>16.0</td></tr><tr><td>1010729</td><td>70</td><td>517</td><td>0.0</td><td>19.0</td></tr><tr><td>1010730</td><td>-4</td><td>353</td><td>0.0</td><td>26.0</td></tr><tr><td>1010730</td><td>-3</td><td>505</td><td>0.0</td><td>24.0</td></tr><tr><td>1010730</td><td>-1</td><td>662</td><td>0.0</td><td>12.0</td></tr><tr><td>1010741</td><td>null</td><td>788</td><td>0.0</td><td>18.0</td></tr><tr><td>1010745</td><td>-3</td><td>1379</td><td>0.0</td><td>6.0</td></tr><tr><td>1010810</td><td>-2</td><td>1382</td><td>0.0</td><td>14.0</td></tr><tr><td>1010810</td><td>2</td><td>822</td><td>0.0</td><td>13.0</td></tr><tr><td>1010810</td><td>29</td><td>288</td><td>0.0</td><td>65.0</td></tr><tr><td>1010810</td><td>42</td><td>605</td><td>0.0</td><td>27.0</td></tr><tr><td>1010810</td><td>null</td><td>1691</td><td>0.0</td><td>3.0</td></tr><tr><td>1010812</td><td>-11</td><td>599</td><td>0.0</td><td>5.0</td></tr><tr><td>1010815</td><td>-2</td><td>1859</td><td>0.0</td><td>7.0</td></tr><tr><td>1010815</td><td>-1</td><td>1896</td><td>0.0</td><td>17.0</td></tr><tr><td>1010815</td><td>1</td><td>1344</td><td>0.0</td><td>49.0</td></tr><tr><td>1010820</td><td>-7</td><td>475</td><td>0.0</td><td>25.0</td></tr><tr><td>1010820</td><td>2</td><td>513</td><td>0.0</td><td>21.0</td></tr><tr><td>1010825</td><td>-3</td><td>473</td><td>0.0</td><td>46.0</td></tr><tr><td>1010830</td><td>-5</td><td>447</td><td>0.0</td><td>43.0</td></tr><tr><td>1010830</td><td>-5</td><td>788</td><td>0.0</td><td>18.0</td></tr><tr><td>1010830</td><td>-1</td><td>747</td><td>0.0</td><td>53.0</td></tr><tr><td>1010830</td><td>0</td><td>581</td><td>0.0</td><td>45.0</td></tr><tr><td>1010830</td><td>8</td><td>475</td><td>0.0</td><td>25.0</td></tr><tr><td>1010830</td><td>11</td><td>605</td><td>0.0</td><td>27.0</td></tr><tr><td>1010830</td><td>12</td><td>516</td><td>0.0</td><td>16.0</td></tr><tr><td>1010831</td><td>-4</td><td>661</td><td>0.0</td><td>56.0</td></tr><tr><td>1010835</td><td>-2</td><td>353</td><td>0.0</td><td>26.0</td></tr><tr><td>1010840</td><td>-5</td><td>279</td><td>0.0</td><td>69.0</td></tr><tr><td>1010840</td><td>null</td><td>473</td><td>0.0</td><td>46.0</td></tr><tr><td>1010840</td><td>null</td><td>1042</td><td>0.0</td><td>4.0</td></tr><tr><td>1010840</td><td>null</td><td>501</td><td>0.0</td><td>20.0</td></tr><tr><td>1010845</td><td>0</td><td>662</td><td>0.0</td><td>12.0</td></tr><tr><td>1010850</td><td>-5</td><td>197</td><td>0.0</td><td>9.0</td></tr><tr><td>1010850</td><td>0</td><td>516</td><td>0.0</td><td>16.0</td></tr><tr><td>1010853</td><td>0</td><td>505</td><td>0.0</td><td>24.0</td></tr><tr><td>1010855</td><td>-2</td><td>351</td><td>0.0</td><td>10.0</td></tr><tr><td>1010855</td><td>-1</td><td>760</td><td>0.0</td><td>44.0</td></tr><tr><td>1010856</td><td>1</td><td>579</td><td>0.0</td><td>22.0</td></tr><tr><td>1010856</td><td>null</td><td>648</td><td>0.0</td><td>11.0</td></tr><tr><td>1010859</td><td>79</td><td>822</td><td>0.0</td ...

# %%
x_df = (
  df_indexed.alias("o")
    .join(imputed_df.alias("i"),
          (df_indexed["date"] == imputed_df["date"]) &
          (df_indexed["distance"] == imputed_df["distance"]) &
          (df_indexed["origin_index"] == imputed_df["origin_index"]) &
          (df_indexed["destination_index"] == imputed_df["destination_index"])
         )
)

x_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: 1239766</div>

# %%
display(x_df.filter(pyf.col("o.delay").isNull()))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>date</th><th>delay</th><th>distance</th><th>origin_index</th><th>destination_index</th><th>date</th><th>delay</th><th>distance</th><th>origin_index</th><th>destination_index</th></tr></thead><tbody><tr><td>1010859</td><td>null</td><td>1585</td><td>5.0</td><td>30.0</td><td>1010859</td><td>1642</td><td>1585</td><td>5.0</td><td>30.0</td></tr><tr><td>1011059</td><td>null</td><td>139</td><td>11.0</td><td>72.0</td><td>1011059</td><td>1642</td><td>139</td><td>11.0</td><td>72.0</td></tr><tr><td>1011500</td><td>null</td><td>207</td><td>0.0</td><td>239.0</td><td>1011500</td><td>1642</td><td>207</td><td>0.0</td><td>239.0</td></tr><tr><td>1011505</td><td>null</td><td>660</td><td>0.0</td><td>15.0</td><td>1011505</td><td>1642</td><td>660</td><td>0.0</td><td>15.0</td></tr><tr><td>1011550</td><td>null</td><td>825</td><td>10.0</td><td>12.0</td><td>1011550</td><td>1642</td><td>825</td><td>10.0</td><td>12.0</td></tr><tr><td>1020820</td><td>null</td><td>1192</td><td>8.0</td><td>31.0</td><td>1020820</td><td>1642</td><td>1192</td><td>8.0</td><td>31.0</td></tr><tr><td>1020829</td><td>null</td><td>64</td><td>5.0</td><td>166.0</td><td>1020829</td><td>1642</td><td>64</td><td>5.0</td><td>166.0</td></tr><tr><td>1020835</td><td>null</td><td>429</td><td>6.0</td><td>76.0</td><td>1020835</td><td>1642</td><td>429</td><td>6.0</td><td>76.0</td></tr><tr><td>1020840</td><td>null</td><td>751</td><td>2.0</td><td>52.0</td><td>1020840</td><td>1642</td><td>751</td><td>2.0</td><td>52.0</td></tr><tr><td>1021220</td><td>null</td><td>336</td><td>8.0</td><td>40.0</td><td>1021220</td><td>1642</td><td>336</td><td>8.0</td><td>40.0</td></tr><tr><td>1021358</td><td>null</td><td>579</td><td>0.0</td><td>22.0</td><td>1021358</td><td>1642</td><td>579</td><td>0.0</td><td>22.0</td></tr><tr><td>1021645</td><td>null</td><td>205</td><td>8.0</td><td>3.0</td><td>1021645</td><td>1642</td><td>205</td><td>8.0</td><td>3.0</td></tr><tr><td>1021942</td><td>null</td><td>418</td><td>0.0</td><td>64.0</td><td>1021942</td><td>1642</td><td>418</td><td>0.0</td><td>64.0</td></tr><tr><td>1022250</td><td>null</td><td>139</td><td>6.0</td><td>158.0</td><td>1022250</td><td>1642</td><td>139</td><td>6.0</td><td>158.0</td></tr><tr><td>1030715</td><td>null</td><td>1388</td><td>5.0</td><td>13.0</td><td>1030715</td><td>1642</td><td>1388</td><td>5.0</td><td>13.0</td></tr><tr><td>1031341</td><td>null</td><td>265</td><td>5.0</td><td>35.0</td><td>1031341</td><td>1642</td><td>265</td><td>5.0</td><td>35.0</td></tr><tr><td>1031445</td><td>null</td><td>513</td><td>9.0</td><td>46.0</td><td>1031445</td><td>1642</td><td>513</td><td>9.0</td><td>46.0</td></tr><tr><td>1031622</td><td>null</td><td>287</td><td>0.0</td><td>176.0</td><td>1031622</td><td>1642</td><td>287</td><td>0.0</td><td>176.0</td></tr><tr><td>1031705</td><td>null</td><td>2160</td><td>3.0</td><td>54.0</td><td>1031705</td><td>1642</td><td>2160</td><td>3.0</td><td>54.0</td></tr><tr><td>1031731</td><td>null</td><td>615</td><td>11.0</td><td>97.0</td><td>1031731</td><td>1642</td><td>615</td><td>11.0</td><td>97.0</td></tr><tr><td>1031740</td><td>null</td><td>260</td><td>2.0</td><td>82.0</td><td>1031740</td><td>1642</td><td>260</td><td>2.0</td><td>82.0</td></tr><tr><td>1031741</td><td>null</td><td>646</td><td>5.0</td><td>51.0</td><td>1031741</td><td>1642</td><td>646</td><td>5.0</td><td>51.0</td></tr><tr><td>1031950</td><td>null</td><td>805</td><td>1.0</td><td>50.0</td><td>1031950</td><td>1642</td><td>805</td><td>1.0</td><td>50.0</td></tr><tr><td>1032045</td><td>null</td><td>525</td><td>1.0</td><td>94.0</td><td>1032045</td><td>1642</td><td>525</td><td>1.0</td><td>94.0</td></tr><tr><td>1032209</td><td>null</td><td>473</td><td>9.0</td><td>12.0</td><td>1032209</td><td>1642</td><td>473</td><td>9.0</td><td>12.0</td></tr><tr><td>1040811</td><td>null</td><td>137</td><td>7.0</td><td>76.0</td><td>1040811</td><td>1642</td><td>137</td><td>7.0</td><td>76.0</td></tr ...

# %%
imputed_df.groupBy("delay").count().orderBy(pyf.desc("delay")).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+------+
# delay| count|
# +-----+------+
#  1642|111196|
#  1636|     1|
#  1553|     1|
#  1511|     1|
#  1500|     1|
#  1496|     1|
#  1482|     1|
#  1470|     1|
#  1461|     2|
#  1444|     1|
#  1418|     1|
#  1417|     1|
#  1404|     1|
#  1400|     1|
#  1350|     1|
#  1321|     1|
#  1308|     1|
#  1288|     1|
#  1238|     1|
#  1191|     1|
# +-----+------+
# only showing top 20 rows
#
# </div>
